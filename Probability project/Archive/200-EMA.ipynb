# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.graph_objects as go
import talib as ta

# %%
data = pd.read_csv('/Users/tejasmadhukar/Downloads/RELIANCE.NS.csv')
data['Date'] = pd.to_datetime(data['Date'])
data['200SMA'] = data['Close'].rolling(200).mean()
data = data.dropna(how ='any') 
data
# Out:
#            Date         Open         High          Low        Close  \
# 240  2015-12-22   491.738800   496.592804   487.380127   489.014618
# 241  2015-12-23   491.243500   498.722595   490.351959   497.187164
# 242  2015-12-24   497.236694   498.871185   493.472382   495.577423
# 243  2015-12-28   495.602173   502.115448   495.304993   500.456177
# 244  2015-12-29   500.456177   504.567200   498.846436   502.932709
# ...         ...          ...          ...          ...          ...
# 1950 2022-11-24  2566.000000  2594.000000  2548.199951  2579.100098
# 1951 2022-11-25  2589.000000  2624.899902  2582.100098  2617.600098
# 1952 2022-11-28  2608.899902  2721.050049  2502.000000  2707.550049
# 1953 2022-11-29  2703.949951  2731.649902  2694.000000  2712.199951
# 1954 2022-11-30  2712.500000  2745.449951  2698.199951  2731.350098
#
#         Adj Close      Volume       200SMA
# 240    470.182281   5343834.0   455.399642
# 241    478.040070   5962332.0   455.745241
# ...

# %%
def trade(data,i,arr):
    if(i==len(data['Close'])-1):
        return
    sl = data['Low'].values[i]
    entry = data['Open'].values[i+1]
    target =

# %%
arr = []
for i in range(len(data['Close'])):
    if(data['close'].values[i]>data['200SMA'].values[i]):
        trade(data,i,arr)
